# %%
# !pip install scipy==1.1.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 15.6 MB 5.2 MB/s
# ...
#   Created wheel for scipy: filename=scipy-1.1.0-cp38-cp38-linux_x86_64.whl size=41833000 sha256=9fb293859667e099c08b569ac7ccc524c3bf69aa325f7b5355586c40f2038a0c
#   Stored in directory: /root/.cache/pip/wheels/29/a9/5e/9e4eddde37a1e15cf5cb404ba197df482cc39ffbfef91ec337
# Successfully built scipy
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.3
#     Uninstalling scipy-1.7.3:
#       Successfully uninstalled scipy-1.7.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xarray-einstats 0.4.0 requires scipy>=1.6, but you have scipy 1.1.0 which is incompatible.
# pymc 4.1.4 requires scipy>=1.4.1, but you have scipy 1.1.0 which is incompatible.
# ...

# %%
from scipy.misc import imread
import matplotlib.pyplot as plt

# %% [markdown]
# # Read and Display the Input Image

# %%
filename = '/content/73_sample.png'
img = imread(filename)
plt.imshow(img, cmap='gray')
# Out:
# <ipython-input-4-a1f7868bddc2>:2: DeprecationWarning:     `imread` is deprecated!
#     `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imread`` instead.
#   img = imread(filename)

# %%
# !python /content/drive/MyDrive/Image_forensics/task2_2nd/Two-stream-Encoder-Decoder-Network-for-Image-Forensics-main/encoder_decoder_train_2_decoder_Synthetic_NIST_Test_tf.py --input_image '/content/73_sample.png' --output_filename 'sample'
# Out:
# 2022-12-23 13:01:07.579002: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_2 (InputLayer)           [(None, 256, 256, 1  0           []
#                                 )]
#
#  constrain (Conv2D)             (None, 256, 256, 3)  78          ['input_2[0][0]']
#
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_16 (Conv2D)             (None, 256, 256, 32  896         ['constrain[0][0]']
#                                 )
#
# ...

# %%
filename = '/content/sample_predicted_mask.png'
img = imread(filename)
plt.imshow(img, 'gray')
# Out:
# <ipython-input-5-0dff1dfe44a9>:2: DeprecationWarning:     `imread` is deprecated!
#     `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imread`` instead.
#   img = imread(filename)

# %% [markdown]
# # Display the Input Image and Predicted Output

# %%
filename_input = '/content/drive/MyDrive/Image_forensics/task2_2nd/Two-stream-Encoder-Decoder-Network-for-Image-Forensics-main/sample_images/NC2016_0211_sample.png'  ## Input Filename
input_img1 = imread(filename_input)

filename_input_gt_mask = '/content/drive/MyDrive/Image_forensics/task2_2nd/Two-stream-Encoder-Decoder-Network-for-Image-Forensics-main/sample_images/NC2016_0211_sample_gt_mask.png'  ## Input Filename
input_gt_mask1 = imread(filename_input_gt_mask)

filename_output = '/content/drive/MyDrive/Image_forensics/task2_2nd/Two-stream-Encoder-Decoder-Network-for-Image-Forensics-main/sample_images/NC2016_0211_sample_predicted_binary_mask.png'
pred_img1 = imread(filename_output)


filename_input = '/content/drive/MyDrive/Image_forensics/task2_2nd/Two-stream-Encoder-Decoder-Network-for-Image-Forensics-main/sample_images/cover_73_sample.png'  ## Input Filename
input_img2 = imread(filename_input)

filename_input_gt_mask = '/content/drive/MyDrive/Image_forensics/task2_2nd/Two-stream-Encoder-Decoder-Network-for-Image-Forensics-main/sample_images/cover_73_sample_gt_mask.png'  ## Input Filename
input_gt_mask2 = imread(filename_input_gt_mask)

filename_output = '/content/drive/MyDrive/Image_forensics/task2_2nd/Two-stream-Encoder-Decoder-Network-for-Image-Forensics-main/sample_images/cover_73_predicted_binary_mask.png'
pred_img2 = imread(filename_output)


filename_input = '/content/drive/MyDrive/Image_forensics/task2_2nd/Two-stream-Encoder-Decoder-Network-for-Image-Forensics-main/sample_images/splicing-08.png'  ## Input Filename
input_img3 = imread(filename_input)

filename_input_gt_mask = '/content/drive/MyDrive/Image_forensics/task2_2nd/Two-stream-Encoder-Decoder-Network-for-Image-Forensics-main/sample_images/splicing-08_gt_mask.png'  ## Input Filename
input_gt_mask3 = imread(filename_input_gt_mask)

filename_output = '/content/drive/MyDrive/Image_forensics/task2_2nd/Two-stream-Encoder-Decoder-Network-for-Image-Forensics-main/sample_images/splicing-08_predicted_binary_mask.png'
pred_img3 = imread(filename_output)


###############  Display the output  ########################################

fig = plt.figure(frameon=False, figsize=(15, 7), dpi=200)


fig.add_subplot(331)
plt.imshow(input_img1, cmap='gray')
plt.title('Input Image')
plt.axis('off')

fig.add_subplot(332)
plt.imshow(input_gt_mask1, cmap='gray')
plt.title('Ground Truth')
plt.axis('off')

fig.add_subplot(333)
plt.imshow(pred_img1, cmap='gray')
plt.title('Output Prediction')
plt.axis('off')


fig.add_subplot(334)
plt.imshow(input_img2, cmap='gray')
plt.title('Input Image')
plt.axis('off')

fig.add_subplot(335)
plt.imshow(input_gt_mask2, cmap='gray')
plt.title('Ground Truth')
plt.axis('off')

fig.add_subplot(336)
plt.imshow(pred_img2, cmap='gray')
plt.title('Output Prediction')
plt.axis('off')

fig.add_subplot(337)
plt.imshow(input_img3, cmap='gray')
plt.title('Input Image')
plt.axis('off')

fig.add_subplot(338)
plt.imshow(input_gt_mask3, cmap='gray')
plt.title('Ground Truth')
plt.axis('off')

fig.add_subplot(339)
plt.imshow(pred_img3, cmap='gray')
plt.title('Output Prediction')
plt.axis('off')

#############################################################################
# Out:
# <ipython-input-4-209bd0574762>:2: DeprecationWarning:     `imread` is deprecated!
#     `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imread`` instead.
#   input_img1 = imread(filename_input)
# <ipython-input-4-209bd0574762>:5: DeprecationWarning:     `imread` is deprecated!
#     `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imread`` instead.
#   input_gt_mask1 = imread(filename_input_gt_mask)
# <ipython-input-4-209bd0574762>:8: DeprecationWarning:     `imread` is deprecated!
#     `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imread`` instead.
#   pred_img1 = imread(filename_output)
# <ipython-input-4-209bd0574762>:12: DeprecationWarning:     `imread` is deprecated!
#     `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imread`` instead.
#   input_img2 = imread(filename_input)
# ...
