# %% [markdown]
# # Train

# %%
# !pip install scipy==1.1.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scipy==1.1.0
#   Downloading scipy-1.1.0.tar.gz (15.6 MB)
#      |████████████████████████████████| 15.6 MB 14.3 MB/s
# Building wheels for collected packages: scipy
#   Building wheel for scipy (setup.py) ... done
#   Created wheel for scipy: filename=scipy-1.1.0-cp38-cp38-linux_x86_64.whl size=41834292 sha256=179cd2fa1abf34ff165383b5789a9d5c229fafb7838a51418421594a41c831e2
#   Stored in directory: /root/.cache/pip/wheels/29/a9/5e/9e4eddde37a1e15cf5cb404ba197df482cc39ffbfef91ec337
# Successfully built scipy
# Installing collected packages: scipy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.3
#     Uninstalling scipy-1.7.3:
#       Successfully uninstalled scipy-1.7.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xarray-einstats 0.4.0 requires scipy>=1.6, but you have scipy 1.1.0 which is incompatible.
# pymc 4.1.4 requires scipy>=1.4.1, but you have scipy 1.1.0 which is incompatible.
# plotnine 0.8.0 requires scipy>=1.5.0, but you have scipy 1.1.0 which is incompatible.
# jaxlib 0.3.25+cuda11.cudnn805 requires scipy>=1.5, but you have scipy 1.1.0 which is incompatible.
# jax 0.3.25 requires scipy>=1.5, but you have scipy 1.1.0 which is incompatible.
# aeppl 0.0.33 requires scipy>=1.4.0, but you have scipy 1.1.0 which is incompatible.
# Successfully installed scipy-1.1.0

# %%
import tensorflow as tf
import tensorflow 
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import SGD,Adam
from tensorflow.keras.losses import binary_crossentropy
import numpy as np
import os
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization, UpSampling2D
import argparse
import keras
np.random.seed(123)
from scipy import signal
from scipy.misc import imread, imsave, imresize
#keras.backend.set_image_data_format('channels_first')

# %%
#Function to normalise and prepare univ layer kernel
def normalise(w):
	j = int(w.shape[0]/2)
	for i in range(w.shape[-1]):
		w[j,j,:,i]= 0
		wsum = w[:,:,:,i].sum()
		w[:,:,:,i]/=wsum
		w[j,j,:,i]=-1
	return w

w = np.random.rand(5,5,1,3)
wgt = normalise(w)
bias = np.zeros(3)

### SRM filter kernels

### For Fixed HPF 
#ww = np.random.rand(5,5,1,3)

w =  np.zeros([5,5,1,3])

"""first filter initializer"""
w[1,1,0,0]=-1/4.0
w[1,2,0,0]=2/4.0
w[1,3,0,0]=-1/4.0
w[2,1,0,0]=2/4.0
w[2,2,0,0]=-4/4.0
w[2,3,0,0]=2/4.0
w[3,1,0,0]=-1/4.0
w[3,2,0,0]=2/4.0
w[3,3,0,0]=-1/4.0

""" Second filter initilizer """
w[0,0,0,1]=-1/12.0
w[0,1,0,1]=2/12.0
w[0,2,0,1]=-2/12.0
w[0,3,0,1]=2/12.0
w[0,4,0,1]=-1/12.0

w[1,0,0,1]=2/12.0
w[1,1,0,1]=-6/12.0
w[1,2,0,1]=8/12.0
w[1,3,0,1]=-6/12.0
w[1,4,0,1]=2/12.0
        
w[2,0,0,1]=-2/12.0
w[2,1,0,1]=8/12.0
w[2,2,0,1]=-12/12.0
w[2,3,0,1]=8/12.0
w[2,4,0,1]=-2/12.0
        
w[3,0,0,1]=2/12.0
w[3,1,0,1]=-6/12.0
w[3,2,0,1]=8/12.0
w[3,3,0,1]=-6/12.0
w[3,4,0,1]=2/12.0

w[4,0,0,1]=-1/12.0
w[4,1,0,1]=2/12.0
w[4,2,0,1]=-2/12.0
w[4,3,0,1]=2/12.0
w[4,4,0,1]=-1/12.0

""" Third Filter """
w[2,1,0,2] = 1/2.0
w[2,2,0,2] = -2/2.0
w[2,3,0,2] = 1/2.0

bias = np.zeros(3)




#### Dice Loss
def dice_coef(y_true, y_pred, axis = (1,2), smooth = 1e-5):
    l = tf.reduce_sum(y_true, axis=axis)
    r = tf.reduce_sum(y_pred, axis=axis)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    dice = (2. * intersection + smooth) / (l + r + smooth)
    dice = tf.reduce_mean(dice)
    return dice


def dice_coef_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)





def conv_mask_gt(z): 
    # Get ones for each class instead of a number -- we need that
    # for cross-entropy loss later on. Sometimes the groundtruth
    # masks have values other than 1 and 0. 
    class_labels_tensor = (z>=1)
    background_labels_tensor = (z==0)

    # Convert the boolean values into floats -- so that
    # computations in cross-entropy loss is correct
    bit_mask_class = np.float32(class_labels_tensor)
    bit_mask_background = np.float32(background_labels_tensor)
    combined_mask=[]
    combined_mask.append(bit_mask_background)
    combined_mask.append(bit_mask_class)
    #combined_mask = tf.concat(concat_dim=3, values=[bit_mask_background,bit_mask_class])		

    # Lets reshape our input so that it becomes suitable for 
    # tf.softmax_cross_entropy_with_logits with [batch_size, num_classes]
    #flat_labels = tf.reshape(tensor=combined_mask, shape=(-1, 2))	
    return combined_mask#flat_labels



def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

def ResUnit(x, nFilter,conv_first=False):
    activation = 'relu'
    batch_normalization = True
    strides = 1
    if conv_first:
        activation = None
        batch_normalization = False
    

    # bottleneck residual unit
    y = resnet_layer(inputs=x,
                     num_filters=nFilter,
                     kernel_size=1,
                     strides=strides,
                     activation=activation,
                     batch_normalization=batch_normalization,
                     conv_first=conv_first)
    y = resnet_layer(inputs=y,
                     num_filters=nFilter,
                     conv_first=False)
    y = resnet_layer(inputs=y,
                     num_filters=nFilter,
                     kernel_size=1,
                     conv_first=False)
   
    x = tensorflow.keras.layers.add([x, y])
    return x

def noiseResidue(input_image, filter_w):
    I = np.float32(input_image[:,:,0])
    
    size = input_image.shape
    
    w1 = filter_w[:,:,0,0]
    w2 = filter_w[:,:,0,1]
    w3 = filter_w[:,:,0,2]
    
    C1 = signal.convolve2d(I, w1, boundary='symm', mode='same')
    C2 = signal.convolve2d(I, w2, boundary='symm', mode='same')
    C3 = signal.convolve2d(I, w3, boundary='symm', mode='same')
    C = np.zeros(size)
    C[:,:,0] = C1
    C[:,:,1] = C2
    C[:,:,2] = C3
    
    #C = block_reduce(C, (4,4,1), func=np.max)    #  downsamples the residual matrix
    return C








nFilter = 32
input_shape=(256, 256, 3)

## RGB Stream of the Encoder

inputs_R = Input(shape=input_shape)
layer_11 = resnet_layer(inputs=inputs_R,
                     num_filters=nFilter,
                     conv_first=True)
layer_11 = ResUnit(layer_11, nFilter)
layer_11 = MaxPooling2D(pool_size=(2,2), strides=(2,2))(layer_11)

layer_12 = resnet_layer(inputs=layer_11,
                     num_filters=2*nFilter,
                     conv_first=False)
layer_12 = ResUnit(layer_12, 2*nFilter)
layer_12 = MaxPooling2D(pool_size=(2,2), strides=(2,2))(layer_12)

layer_13 = resnet_layer(inputs=layer_12,
                     num_filters=4*nFilter,
                     conv_first=False)
layer_13 = ResUnit(layer_13, 4*nFilter)
layer_13 = MaxPooling2D(pool_size=(2,2), strides=(2,2))(layer_13)

layer_14 = resnet_layer(inputs=layer_13,
                     num_filters=8*nFilter,
                     conv_first=False)
layer_14 = ResUnit(layer_14, 8*nFilter)
layer_14 = MaxPooling2D(pool_size=(2,2), strides=(2,2))(layer_14)



## Noise Stream of the Encoder

input_shape_N = (256, 256, 1)
inputs_N = Input(shape=input_shape_N)
layer_21 = Conv2D(3, (5, 5), input_shape=input_shape, padding="same", name='constrain')(inputs_N)
layer_21 = resnet_layer(inputs=layer_21,
                     num_filters=nFilter,
                     conv_first=True)
layer_21 = ResUnit(layer_21, nFilter)
layer_21 = MaxPooling2D(pool_size=(2,2), strides=(2,2))(layer_21)

layer_22 = resnet_layer(inputs=layer_21,
                     num_filters=2*nFilter,
                     conv_first=False)
layer_22 = ResUnit(layer_22, 2*nFilter)
layer_22 = MaxPooling2D(pool_size=(2,2), strides=(2,2))(layer_22)

layer_23 = resnet_layer(inputs=layer_22,
                     num_filters=4*nFilter,
                     conv_first=False)
layer_23 = ResUnit(layer_23, 4*nFilter)
layer_23 = MaxPooling2D(pool_size=(2,2), strides=(2,2))(layer_23)

layer_24 = resnet_layer(inputs=layer_23,
                     num_filters=8*nFilter,
                     conv_first=False)
layer_24 = ResUnit(layer_24, 8*nFilter)
layer_24 = MaxPooling2D(pool_size=(2,2), strides=(2,2))(layer_24)



concatenated = tensorflow.keras.layers.concatenate([layer_14, layer_24])

## Fused Decoder
fused_d_layer1 = UpSampling2D(size=(2, 2))(concatenated)
fused_d_layer1 = resnet_layer(inputs=fused_d_layer1,
                     num_filters=2*nFilter,
                     conv_first=False)

fused_d_layer2 = UpSampling2D(size=(2, 2))(fused_d_layer1)
fused_d_layer2 = resnet_layer(inputs=fused_d_layer2,
                     num_filters=2*nFilter,
                     conv_first=False)


fused_d_layer3 = UpSampling2D(size=(2, 2))(fused_d_layer2)
fused_d_layer3 = resnet_layer(inputs=fused_d_layer3,
                     num_filters=1*nFilter,
                     conv_first=False)

fused_d_layer4 = UpSampling2D(size=(2, 2))(fused_d_layer3)
fused_d_layer4 = resnet_layer(inputs=fused_d_layer4,
                     num_filters=nFilter,
                     conv_first=False)


## Noise Decoder
noise_d_layer1 = UpSampling2D(size=(2, 2))(layer_24)
noise_d_layer1 = resnet_layer(inputs=noise_d_layer1,
                     num_filters=2*nFilter,
                     conv_first=False)

noise_d_layer2 = UpSampling2D(size=(2, 2))(noise_d_layer1)
noise_d_layer2 = resnet_layer(inputs=noise_d_layer2,
                     num_filters=2*nFilter,
                     conv_first=False)


noise_d_layer3 = UpSampling2D(size=(2, 2))(noise_d_layer2)
noise_d_layer3 = resnet_layer(inputs=noise_d_layer3,
                     num_filters=1*nFilter,
                     conv_first=False)

noise_d_layer4 = UpSampling2D(size=(2, 2))(noise_d_layer3)
noise_d_layer4 = resnet_layer(inputs=noise_d_layer4,
                     num_filters=nFilter,
                     conv_first=False)


## RGB Decoder
rgb_d_layer1 = UpSampling2D(size=(2, 2))(layer_14)
rgb_d_layer1 = resnet_layer(inputs=rgb_d_layer1,
                     num_filters=2*nFilter,
                     conv_first=False)

rgb_d_layer2 = UpSampling2D(size=(2, 2))(rgb_d_layer1)
rgb_d_layer2 = resnet_layer(inputs=rgb_d_layer2,
                     num_filters=2*nFilter,
                     conv_first=False)


rgb_d_layer3 = UpSampling2D(size=(2, 2))(rgb_d_layer2)
rgb_d_layer3 = resnet_layer(inputs=rgb_d_layer3,
                     num_filters=1*nFilter,
                     conv_first=False)

rgb_d_layer4 = UpSampling2D(size=(2, 2))(rgb_d_layer3)
rgb_d_layer4 = resnet_layer(inputs=rgb_d_layer4,
                     num_filters=nFilter,
                     conv_first=False)

decoder_concatenated = tensorflow.keras.layers.concatenate([noise_d_layer4, rgb_d_layer4])

fused_decoder = Conv2D(1, (1, 1), activation='sigmoid', padding='same')(decoder_concatenated)

# Instantiate model.
model = Model(inputs=[inputs_N, inputs_R], outputs=fused_decoder)

optimizer = tensorflow.keras.optimizers.Adam(lr=0.0005)

model.compile(loss=dice_coef_loss,
              optimizer=optimizer,
              metrics=['accuracy', dice_coef])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 256, 256, 1  0           []
#                                 )]
#
#  constrain (Conv2D)             (None, 256, 256, 3)  78          ['input_2[0][0]']
#
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_16 (Conv2D)             (None, 256, 256, 32  896         ['constrain[0][0]']
#                                 )
#
#  conv2d (Conv2D)                (None, 256, 256, 32  896         ['input_1[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 256, 256, 32  128        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  batch_normalization (BatchNorm  (None, 256, 256, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  activation_16 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  activation (Activation)        (None, 256, 256, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 256, 256, 32  128        ['activation_16[0][0]']
#  ormalization)                  )
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 32  128        ['activation[0][0]']
#  rmalization)                   )
#
#  activation_17 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  activation_1 (Activation)      (None, 256, 256, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 256, 256, 32  1056        ['activation_17[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 32  1056        ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_18 (BatchN  (None, 256, 256, 32  128        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  batch_normalization_2 (BatchNo  (None, 256, 256, 32  128        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_18 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_18[0][0]']
#                                 )
#
#  activation_2 (Activation)      (None, 256, 256, 32  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 256, 256, 32  9248        ['activation_18[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 32  9248        ['activation_2[0][0]']
#                                 )
#
#  batch_normalization_19 (BatchN  (None, 256, 256, 32  128        ['conv2d_18[0][0]']
#  ormalization)                  )
#
#  batch_normalization_3 (BatchNo  (None, 256, 256, 32  128        ['conv2d_2[0][0]']
#  rmalization)                   )
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
#
#  activation_19 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_19[0][0]']
#                                 )
#
#  activation_3 (Activation)      (None, 256, 256, 32  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  conv2d_19 (Conv2D)             (None, 256, 256, 32  1056        ['activation_19[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 256, 256, 32  1056        ['activation_3[0][0]']
#                                 )
#
#  add_4 (Add)                    (None, 256, 256, 32  0           ['activation_16[0][0]',
#                                 )                                 'conv2d_19[0][0]']
#
#  add (Add)                      (None, 256, 256, 32  0           ['activation[0][0]',
#                                 )                                 'conv2d_3[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 128, 128, 32  0          ['add_4[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 32  0           ['add[0][0]']
#                                 )
#
#  batch_normalization_20 (BatchN  (None, 128, 128, 32  128        ['max_pooling2d_4[0][0]']
#  ormalization)                  )
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 32  128        ['max_pooling2d[0][0]']
#  rmalization)                   )
#
#  activation_20 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_20[0][0]']
#                                 )
#
#  activation_4 (Activation)      (None, 128, 128, 32  0           ['batch_normalization_4[0][0]']
#                                 )
#
#  conv2d_20 (Conv2D)             (None, 128, 128, 64  18496       ['activation_20[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 64  18496       ['activation_4[0][0]']
#                                 )
#
#  batch_normalization_21 (BatchN  (None, 128, 128, 64  256        ['conv2d_20[0][0]']
#  ormalization)                  )
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 64  256        ['conv2d_4[0][0]']
#  rmalization)                   )
#
#  activation_21 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_21[0][0]']
#                                 )
#
#  activation_5 (Activation)      (None, 128, 128, 64  0           ['batch_normalization_5[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 128, 128, 64  4160        ['activation_21[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 64  4160        ['activation_5[0][0]']
#                                 )
#
#  batch_normalization_22 (BatchN  (None, 128, 128, 64  256        ['conv2d_21[0][0]']
#  ormalization)                  )
#
#  batch_normalization_6 (BatchNo  (None, 128, 128, 64  256        ['conv2d_5[0][0]']
#  rmalization)                   )
#
#  activation_22 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_22[0][0]']
#                                 )
#
#  activation_6 (Activation)      (None, 128, 128, 64  0           ['batch_normalization_6[0][0]']
#                                 )
#
#  conv2d_22 (Conv2D)             (None, 128, 128, 64  36928       ['activation_22[0][0]']
#                                 )
#
#  conv2d_6 (Conv2D)              (None, 128, 128, 64  36928       ['activation_6[0][0]']
#                                 )
#
#  batch_normalization_23 (BatchN  (None, 128, 128, 64  256        ['conv2d_22[0][0]']
#  ormalization)                  )
#
#  batch_normalization_7 (BatchNo  (None, 128, 128, 64  256        ['conv2d_6[0][0]']
#  rmalization)                   )
#
#  activation_23 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_23[0][0]']
#                                 )
#
#  activation_7 (Activation)      (None, 128, 128, 64  0           ['batch_normalization_7[0][0]']
#                                 )
#
#  conv2d_23 (Conv2D)             (None, 128, 128, 64  4160        ['activation_23[0][0]']
#                                 )
#
#  conv2d_7 (Conv2D)              (None, 128, 128, 64  4160        ['activation_7[0][0]']
#                                 )
#
#  add_5 (Add)                    (None, 128, 128, 64  0           ['conv2d_20[0][0]',
#                                 )                                 'conv2d_23[0][0]']
#
#  add_1 (Add)                    (None, 128, 128, 64  0           ['conv2d_4[0][0]',
#                                 )                                 'conv2d_7[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 64, 64, 64)  0           ['add_5[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 64)  0           ['add_1[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 64, 64, 64)  256         ['max_pooling2d_5[0][0]']
#  ormalization)
#
#  batch_normalization_8 (BatchNo  (None, 64, 64, 64)  256         ['max_pooling2d_1[0][0]']
#  rmalization)
#
#  activation_24 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_24[0][0]']
#
#  activation_8 (Activation)      (None, 64, 64, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 64, 64, 128)  73856       ['activation_24[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 64, 64, 128)  73856       ['activation_8[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 64, 64, 128)  512        ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_9 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_25 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_25[0][0]']
#
#  activation_9 (Activation)      (None, 64, 64, 128)  0           ['batch_normalization_9[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 64, 64, 128)  16512       ['activation_25[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 64, 64, 128)  16512       ['activation_9[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 64, 64, 128)  512        ['conv2d_25[0][0]']
#  ormalization)
#
#  batch_normalization_10 (BatchN  (None, 64, 64, 128)  512        ['conv2d_9[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_26[0][0]']
#
#  activation_10 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 64, 64, 128)  147584      ['activation_26[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 64, 128)  147584      ['activation_10[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 64, 64, 128)  512        ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 64, 64, 128)  512        ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_27[0][0]']
#
#  activation_11 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 64, 64, 128)  16512       ['activation_27[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 64, 64, 128)  16512       ['activation_11[0][0]']
#
#  add_6 (Add)                    (None, 64, 64, 128)  0           ['conv2d_24[0][0]',
#                                                                   'conv2d_27[0][0]']
#
#  add_2 (Add)                    (None, 64, 64, 128)  0           ['conv2d_8[0][0]',
#                                                                   'conv2d_11[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 32, 32, 128)  0          ['add_6[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 128)  0          ['add_2[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 32, 32, 128)  512        ['max_pooling2d_6[0][0]']
#  ormalization)
#
#  batch_normalization_12 (BatchN  (None, 32, 32, 128)  512        ['max_pooling2d_2[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_28[0][0]']
#
#  activation_12 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 32, 32, 256)  295168      ['activation_28[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 256)  295168      ['activation_12[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_28[0][0]']
#  ormalization)
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_29[0][0]']
#
#  activation_13 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_13[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 32, 32, 256)  65792       ['activation_29[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 256)  65792       ['activation_13[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_29[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_30[0][0]']
#
#  activation_14 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_14[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 32, 32, 256)  590080      ['activation_30[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 256)  590080      ['activation_14[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_15 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_31[0][0]']
#
#  activation_15 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 32, 32, 256)  65792       ['activation_31[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 256)  65792       ['activation_15[0][0]']
#
#  add_7 (Add)                    (None, 32, 32, 256)  0           ['conv2d_28[0][0]',
#                                                                   'conv2d_31[0][0]']
#
#  add_3 (Add)                    (None, 32, 32, 256)  0           ['conv2d_12[0][0]',
#                                                                   'conv2d_15[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 16, 16, 256)  0          ['add_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 256)  0          ['add_3[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 32, 32, 256)  0          ['max_pooling2d_7[0][0]']
#
#  up_sampling2d_8 (UpSampling2D)  (None, 32, 32, 256)  0          ['max_pooling2d_3[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 32, 32, 256)  1024       ['up_sampling2d_4[0][0]']
#  ormalization)
#
#  batch_normalization_40 (BatchN  (None, 32, 32, 256)  1024       ['up_sampling2d_8[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_36[0][0]']
#
#  activation_40 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_40[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 32, 32, 64)   147520      ['activation_36[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 32, 32, 64)   147520      ['activation_40[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 64, 64, 64)  0           ['conv2d_36[0][0]']
#
#  up_sampling2d_9 (UpSampling2D)  (None, 64, 64, 64)  0           ['conv2d_40[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 64, 64, 64)  256         ['up_sampling2d_5[0][0]']
#  ormalization)
#
#  batch_normalization_41 (BatchN  (None, 64, 64, 64)  256         ['up_sampling2d_9[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_37[0][0]']
#
#  activation_41 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_41[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_37[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_41[0][0]']
#
#  up_sampling2d_6 (UpSampling2D)  (None, 128, 128, 64  0          ['conv2d_37[0][0]']
#                                 )
#
#  up_sampling2d_10 (UpSampling2D  (None, 128, 128, 64  0          ['conv2d_41[0][0]']
#  )                              )
#
#  batch_normalization_38 (BatchN  (None, 128, 128, 64  256        ['up_sampling2d_6[0][0]']
#  ormalization)                  )
#
#  batch_normalization_42 (BatchN  (None, 128, 128, 64  256        ['up_sampling2d_10[0][0]']
#  ormalization)                  )
#
#  activation_38 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_38[0][0]']
#                                 )
#
#  activation_42 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_42[0][0]']
#                                 )
#
#  conv2d_38 (Conv2D)             (None, 128, 128, 32  18464       ['activation_38[0][0]']
#                                 )
#
#  conv2d_42 (Conv2D)             (None, 128, 128, 32  18464       ['activation_42[0][0]']
#                                 )
#
#  up_sampling2d_7 (UpSampling2D)  (None, 256, 256, 32  0          ['conv2d_38[0][0]']
#                                 )
#
#  up_sampling2d_11 (UpSampling2D  (None, 256, 256, 32  0          ['conv2d_42[0][0]']
#  )                              )
#
#  batch_normalization_39 (BatchN  (None, 256, 256, 32  128        ['up_sampling2d_7[0][0]']
#  ormalization)                  )
#
#  batch_normalization_43 (BatchN  (None, 256, 256, 32  128        ['up_sampling2d_11[0][0]']
#  ormalization)                  )
#
#  activation_39 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_39[0][0]']
#                                 )
#
#  activation_43 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_43[0][0]']
#                                 )
#
#  conv2d_39 (Conv2D)             (None, 256, 256, 32  9248        ['activation_39[0][0]']
#                                 )
#
#  conv2d_43 (Conv2D)             (None, 256, 256, 32  9248        ['activation_43[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 256, 256, 64  0           ['conv2d_39[0][0]',
#                                 )                                 'conv2d_43[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 256, 256, 1)  65          ['concatenate_1[0][0]']
#
# ==================================================================================================
# Total params: 3,135,951
# Trainable params: 3,127,503
# Non-trainable params: 8,448
# __________________________________________________________________________________________________
# None

# %%
###################################################################################################
#####################   Initial Constraint ########################################################  
#model.get_layer('constrain').set_weights([wgt, bias])

#layer_output = model.get_layer('constrain').get_weights()



###################################################################################################
###### Load the pre-trained model for resuming/finetuning the training
#weight_path = './models/loss/model_weights.hd5'
#model.load_weights(weight_path)


###################################################################################################3

batch_size = 4
test_batch_size = 4
num_iters = 150


img_path2 = '/content/drive/MyDrive/Image_forensics/task2_2nd/data_forgery/CASIA2.0_revised/Tp/'
mask_path2 = '/content/drive/MyDrive/Image_forensics/task2_2nd/data_forgery/masks_casia2.0/CASIA2.0_Groundtruth/'



imgDir2 = os.listdir(img_path2)

imgDirTrain2 = imgDir2[:len(imgDir2)-16]
imgDirTest2 = imgDir2[len(imgDir2)-16:]



batch_x = np.zeros((2*batch_size, 256, 256, 3))
batch_y = np.zeros((2*batch_size,256,256, 1))
batch_x1 = np.zeros((2*batch_size,256,256, 1))

batch_x_val = np.zeros((2*test_batch_size, 256, 256, 3))
batch_y_val = np.zeros((2*test_batch_size,256,256, 1))
batch_x1_val = np.zeros((2*test_batch_size,256,256, 1))


###########  For CopyMove Folder  ##########################
for i in range(test_batch_size):
    name = imgDirTest2[i]
    imgFilename = img_path2 + name
    img = imread(imgFilename)
    maskFilename = mask_path2 + name[:-4] + '_gt.png'
    mask = imread(maskFilename)
    
    img = imresize(img, [256,256,3])
    mask = imresize(mask, [256, 256])
    
    mask_size = mask.shape
    
    
    batch_x_val[test_batch_size+i,:,:,:] = img[:,:,0:3]
    batch_x1_val[test_batch_size+i,:,:,0] = img[:,:,1]
    if(len(mask_size)>2):
        mask1 = mask[:,:,0]
    else:
        mask1 = mask[:,:]
    mask2 = np.asanyarray(conv_mask_gt(mask1))
    mask2 = np.moveaxis(mask2, 1, 0)
    mask2 = np.moveaxis(mask2, 2, 1)
    
    batch_y_val[test_batch_size+i,:,:,0] = mask2[:,:,0]
    

best_loss = 100
best_acc = 0

file_acc = open('/content/drive/MyDrive/Image_forensics/task2_2nd/data_forgery/training/log_acc/log_acc_train.txt', 'a')
file_dice = open('/content/drive/MyDrive/Image_forensics/task2_2nd/data_forgery/training/log_acc/log_dice_train.txt', 'a')
file_loss = open('/content/drive/MyDrive/Image_forensics/task2_2nd/data_forgery/training/log_loss/log_lossdice_train.txt', 'a')

file_acc_test = open('/content/drive/MyDrive/Image_forensics/task2_2nd/data_forgery/training/logs_test/acc/log_acc_test.txt', 'a')
file_dice_test = open('/content/drive/MyDrive/Image_forensics/task2_2nd/data_forgery/training/logs_test/acc/log_dice_test.txt', 'a')
file_loss_test = open('/content/drive/MyDrive/Image_forensics/task2_2nd/data_forgery/training/logs_test/loss/log_lossdice_test.txt', 'a')

for iters in range(num_iters):
    
    print('Epoch count: ', iters)
    
    np.random.shuffle(imgDirTrain2)
    

    ###########  For CopyMove Folder  ##########################
    for b in range(batch_size):
        name = imgDirTrain2[b]
        print('Image Name: ', name)
        imgFilename = img_path2 + name
        img = imread(imgFilename)
        maskFilename = mask_path2 + name[:-4]+ '_gt.png'
        mask = imread(maskFilename)
        
        img = imresize(img, [256,256,3])
        mask = imresize(mask, [256, 256])
        
        mask_size = mask.shape
        
        
        batch_x[batch_size+b,:,:,:] = img[:,:,0:3]
        batch_x1[batch_size+b,:,:,0] = img[:,:,1]
        if(len(mask_size)>2):
            mask1 = mask[:,:,0]
        else:
            mask1 = mask[:,:]
        mask2 = np.asanyarray(conv_mask_gt(mask1))
        mask2 = np.moveaxis(mask2, 1, 0)
        mask2 = np.moveaxis(mask2, 2, 1)
        
        batch_y[batch_size+b,:,:,0] = mask2[:,:,0]
        
            
            
    loss_train, acc_train, dice_score = model.train_on_batch([batch_x1, batch_x], batch_y)
    
    ### constrain on the first layer of the Noise stream encoder ##############
    
    layer_output = model.get_layer('constrain').get_weights()
    layer_weight = layer_output[0]
    layer_bias = layer_output[1]
    
    constrained_weight = normalise(layer_weight)
    model.get_layer('constrain').set_weights([constrained_weight, layer_bias])
    
    ###########################################################################

    

    
    loss_test, acc_test, dice_score_test = model.test_on_batch([batch_x1_val, batch_x_val], batch_y_val)
    
    print('Train loss: ', loss_train, ' acc: ', acc_train, 'Train dice:', dice_score,' Test loss: ', loss_test,  ' acc: ', acc_test, 'Test dice:', dice_score_test)
    
    loss_train_str = str(loss_train) + '\n'
    acc_train_str = str(acc_train) + '\n'
    dice_train_str = str(dice_score) + '\n'

    loss_train_str_test = str(loss_test) + '\n'
    acc_train_str_test = str(acc_test) + '\n'
    dice_train_str_test = str(dice_score_test) + '\n'

    file_acc.write(acc_train_str)
    file_dice.write(dice_train_str)
    file_loss.write(loss_train_str)

    file_acc_test.write(acc_train_str_test)
    file_dice_test.write(dice_train_str_test)
    file_loss_test.write(loss_train_str_test)
    
    if(loss_train <=best_loss):
        print('Model with best loss found..')
        weight_path = '/content/drive/MyDrive/Image_forensics/task2_2nd/data_forgery/training/loss/model_weights_dice.h5'
        model.save_weights(weight_path)
        best_loss = loss_train
    
    if(acc_train >= best_acc):
        print('Model with best acc found..')
        weight_path = '/content/drive/MyDrive/Image_forensics/task2_2nd/data_forgery/training/acc/model_weights_dice.h5'
        model.save_weights(weight_path)
        best_acc = acc_train
            
        
file_acc.close()
file_loss.close()

file_acc_test.close()
file_loss_test.close()

print('.........Training is Done .............')
# Out:
# <ipython-input-3-05dbbae65c1a>:47: DeprecationWarning:     `imread` is deprecated!
#     `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imread`` instead.
#   img = imread(imgFilename)
# <ipython-input-3-05dbbae65c1a>:49: DeprecationWarning:     `imread` is deprecated!
#     `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imread`` instead.
#   mask = imread(maskFilename)
# <ipython-input-3-05dbbae65c1a>:51: DeprecationWarning:     `imresize` is deprecated!
#     `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``skimage.transform.resize`` instead.
#   img = imresize(img, [256,256,3])
# <ipython-input-3-05dbbae65c1a>:52: DeprecationWarning:     `imresize` is deprecated!
#     `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``skimage.transform.resize`` instead.
#   mask = imresize(mask, [256, 256])
# <ipython-input-3-05dbbae65c1a>:93: DeprecationWarning:     `imread` is deprecated!
#     `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imread`` instead.
#   img = imread(imgFilename)
# <ipython-input-3-05dbbae65c1a>:95: DeprecationWarning:     `imread` is deprecated!
#     `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imread`` instead.
#   mask = imread(maskFilename)
# <ipython-input-3-05dbbae65c1a>:97: DeprecationWarning:     `imresize` is deprecated!
#     `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``skimage.transform.resize`` instead.
#   img = imresize(img, [256,256,3])
# <ipython-input-3-05dbbae65c1a>:98: DeprecationWarning:     `imresize` is deprecated!
#     `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``skimage.transform.resize`` instead.
#   mask = imresize(mask, [256, 256])
# Epoch count:  0
# Image Name:  Tp_S_CNN_M_N_sec00017_sec00017_10784.jpg
# Image Name:  Tp_S_NNN_S_N_art20084_art20084_01890.tif
# Image Name:  Tp_D_NND_S_B_art00004_ani00077_01194.tif
# Image Name:  Tp_S_NRD_S_B_nat00038_nat00038_00957.tif
# Train loss:  1.4520220756530762  acc:  0.4053516387939453 Train dice: 0.39345383644104004  Test loss:  1.4099268913269043  acc:  0.40023231506347656 Test dice: 0.43485090136528015
# Model with best loss found..
# Model with best acc found..
# Epoch count:  1
# Image Name:  Tp_D_NNN_S_O_sec20058_sec20053_01648.tif
# Image Name:  Tp_D_NNN_M_N_sec00089_cha00062_11491.jpg
# Image Name:  Tp_S_NNN_S_N_nat10120_nat10120_11340.jpg
# Image Name:  Tp_S_NNN_S_N_pla20077_pla20077_01977.tif
# Train loss:  1.389573574066162  acc:  0.9237480163574219 Train dice: 0.45520418882369995  Test loss:  1.4074983596801758  acc:  0.3954963684082031 Test dice: 0.435966819524765
# Model with best loss found..
# Model with best acc found..
# Epoch count:  2
# Image Name:  Tp_S_NNN_S_N_arc20041_arc20041_02177.tif
# Image Name:  Tp_S_NNN_S_N_ind00016_ind00016_00888.tif
# Image Name:  Tp_D_CRN_S_N_ani10191_ani10190_12437.jpg
# Image Name:  Tp_S_CNN_M_N_arc00062_arc00062_10253.tif
# Train loss:  1.3911428451538086  acc:  0.915374755859375 Train dice: 0.45232242345809937  Test loss:  1.405775785446167  acc:  0.39368629455566406 Test dice: 0.4359697103500366
# Epoch count:  3
# Image Name:  Tp_S_NNN_M_N_cha00044_cha00044_11008.jpg
# Image Name:  Tp_D_NNN_S_B_art20064_nat20042_02325.tif
# Image Name:  Tp_S_CNN_S_N_arc00048_arc00048_10243.tif
# Image Name:  Tp_S_NNN_S_N_arc20086_arc20086_02415.tif
# Train loss:  1.3536688089370728  acc:  0.9634914398193359 Train dice: 0.48807674646377563  Test loss:  1.403706431388855  acc:  0.3936786651611328 Test dice: 0.43596985936164856
# Model with best loss found..
# Model with best acc found..
# Epoch count:  4
# Image Name:  Tp_S_CNN_S_N_pla00099_pla00099_00620.tif
# Image Name:  Tp_S_CNN_S_N_nat00091_nat00091_11098.jpg
# Image Name:  Tp_S_NNN_M_N_ind00071_ind00071_10696.jpg
# Image Name:  Tp_S_NNN_S_B_ind00011_ind00011_00429.tif
# Train loss:  1.354173183441162  acc:  0.9544887542724609 Train dice: 0.4855031371116638  Test loss:  1.4013845920562744  acc:  0.3936786651611328 Test dice: 0.43596988916397095
# Epoch count:  5
# Image Name:  Tp_S_CNN_M_N_pla10116_pla10116_10602.jpg
# Image Name:  Tp_D_NNN_M_N_nat00096_nat00097_11096.jpg
# Image Name:  Tp_S_NRN_S_N_art00083_art00083_01391.tif
# Image Name:  Tp_D_NNN_S_N_sec00007_sec00025_10773.jpg
# Train loss:  1.4211511611938477  acc:  0.84149169921875 Train dice: 0.4162032902240753  Test loss:  1.3988449573516846  acc:  0.3936786651611328 Test dice: 0.43596988916397095
# Epoch count:  6
# Image Name:  Tp_D_NRN_S_N_ani00096_ani00098_11134.jpg
# Train loss:  1.2830052375793457  acc:  0.8940792083740234 Train dice: 0.48844629526138306  Test loss:  1.3314588069915771  acc:  0.8647174835205078 Test dice: 0.43596962094306946
# Model with best loss found..
# Epoch count:  25
# Image Name:  Tp_S_NNN_S_N_arc20091_arc20091_02408.tif
# Image Name:  Tp_D_NRN_M_N_ind10102_cha10112_11547.jpg
# Image Name:  Tp_S_NNN_S_N_art00076_art00076_00530.tif
# Image Name:  Tp_D_NRN_S_N_sec00090_ani00013_00717.tif
# Train loss:  1.2853975296020508  acc:  0.9209823608398438 Train dice: 0.4820309281349182  Test loss:  1.3274126052856445  acc:  0.8669223785400391 Test dice: 0.4359695315361023
# Epoch count:  26
# Image Name:  Tp_D_NRN_S_N_nat10156_ani00031_12018.jpg
# Image Name:  Tp_S_NRN_S_N_nat00034_nat00034_00950.tif
# Image Name:  Tp_S_NRN_M_N_ind00070_ind00070_10694.jpg
# Image Name:  Tp_S_NRD_S_B_art00070_art00070_01029.tif
# Train loss:  1.2721751928329468  acc:  0.9272003173828125 Train dice: 0.4912070035934448  Test loss:  1.3233463764190674  acc:  0.8656864166259766 Test dice: 0.43596935272216797
# Model with best loss found..
# Epoch count:  27
# Image Name:  Tp_D_NRN_M_O_nat10157_nat00095_12046.jpg
# Image Name:  Tp_S_NRN_S_N_ind00019_ind00019_01317.tif
# Image Name:  Tp_S_NNN_S_N_arc20082_arc20082_01722.tif
# Image Name:  Tp_S_NNN_S_N_nat20026_nat20026_01530.tif
# Train loss:  1.3015092611312866  acc:  0.8687248229980469 Train dice: 0.45780640840530396  Test loss:  1.3192628622055054  acc:  0.8646106719970703 Test dice: 0.43596911430358887
# Epoch count:  28
# Image Name:  Tp_S_CRN_M_N_pla00088_pla00088_10852.jpg
# Image Name:  Tp_S_NNN_S_N_arc00094_arc00094_01036.tif
# Image Name:  Tp_S_NRN_S_N_art20043_art20043_01849.tif
# Image Name:  Tp_D_NRN_M_B_cha10142_nat00097_12239.jpg
# Train loss:  1.3112704753875732  acc:  0.8254032135009766 Train dice: 0.44396156072616577  Test loss:  1.31516432762146  acc:  0.8596439361572266 Test dice: 0.4359687864780426
# Epoch count:  29
# Image Name:  Tp_S_NNN_S_B_sec00089_sec00089_11121.jpg
# Image Name:  Tp_S_CRN_M_N_art00058_art00058_10531.tif
# Image Name:  Tp_S_NNN_S_B_cha00057_cha00057_00377.tif
# Image Name:  Tp_S_CRN_M_B_nat00031_nat00031_10095.tif
# Train loss:  1.2776334285736084  acc:  0.8976917266845703 Train dice: 0.47349974513053894  Test loss:  1.3110530376434326  acc:  0.8505344390869141 Test dice: 0.4359683096408844
# Epoch count:  30
# Image Name:  Tp_S_NNN_S_B_nat20052_nat20052_02248.tif
# Image Name:  Tp_S_NRN_S_N_txt00084_txt00084_11302.jpg
# Image Name:  Tp_S_CRN_S_N_txt00047_txt00047_01275.tif
# Image Name:  Tp_S_CNN_S_N_ind00024_ind00024_00439.tif
# Train loss:  1.2561681270599365  acc:  0.8729133605957031 Train dice: 0.4908532202243805  Test loss:  1.3069313764572144  acc:  0.8358860015869141 Test dice: 0.4359675347805023
# Model with best loss found..
# Epoch count:  31
# Image Name:  Tp_D_NRN_M_N_nat10147_nat00095_11998.jpg
# Image Name:  Tp_D_NNN_L_N_cha00074_txt00068_10193.tif
# Image Name:  Tp_D_NRD_S_N_ind00030_ind00031_01323.tif
# Image Name:  Tp_D_NNN_S_N_arc00017_ani00058_00237.tif
# Train loss:  1.3074002265930176  acc:  0.8431758880615234 Train dice: 0.4354986548423767  Test loss:  1.3028008937835693  acc:  0.8308658599853516 Test dice: 0.4359666109085083
# Epoch count:  32
# Image Name:  Tp_D_CRD_S_N_sec00003_sec00007_00023.tif
# Image Name:  Tp_S_NNN_S_N_cha00032_cha00032_00847.tif
# Image Name:  Tp_S_NNN_S_B_art00041_art00041_01225.tif
# Image Name:  Tp_D_CRN_S_N_nat00004_art00025_11426.jpg
# Train loss:  1.2442142963409424  acc:  0.9368915557861328 Train dice: 0.49455320835113525  Test loss:  1.2986637353897095  acc:  0.8292865753173828 Test dice: 0.43596547842025757
# Model with best loss found..
# Epoch count:  33
# Image Name:  Tp_D_NNN_S_N_nat20018_nat20015_01522.tif
# Image Name:  Tp_S_NNN_S_N_ind00029_ind00029_01322.tif
# Image Name:  Tp_S_NNN_S_N_cha20027_cha20027_02026.tif
# Image Name:  Tp_D_NRN_M_N_nat10160_nat10147_12069.jpg
# Train loss:  1.2885411977767944  acc:  0.8663120269775391 Train dice: 0.4460880160331726  Test loss:  1.2945215702056885  acc:  0.8342761993408203 Test dice: 0.43596410751342773
# Epoch count:  34
# Image Name:  Tp_D_CND_S_N_txt00028_txt00006_10848.jpg
# Image Name:  Tp_D_NRN_S_N_pla10120_pla00020_11603.jpg
# Image Name:  Tp_D_NRD_S_N_art00070_art00092_11822.jpg
# Image Name:  Tp_S_CNN_S_N_arc10104_arc10104_10861.jpg
# Train loss:  1.2495007514953613  acc:  0.8695430755615234 Train dice: 0.4809848964214325  Test loss:  1.2903764247894287  acc:  0.8395328521728516 Test dice: 0.4359619915485382
# Epoch count:  35
# Image Name:  Tp_S_NNN_S_N_pla00025_pla00025_00562.tif
# Image Name:  Tp_S_NNN_S_N_pla00029_pla00029_01145.tif
# Image Name:  Tp_S_NNN_S_N_art00036_art00036_01222.tif
# Image Name:  Tp_D_NRN_M_N_nat00025_nat00028_11037.jpg
# Train loss:  1.248776912689209  acc:  0.8967800140380859 Train dice: 0.47756144404411316  Test loss:  1.2862294912338257  acc:  0.8526477813720703 Test dice: 0.4359596073627472
# Epoch count:  36
# Image Name:  Tp_D_NNN_M_N_sec00058_nat00097_11273.jpg
# Image Name:  Tp_S_NRD_S_B_ani00061_ani00061_00181.tif
# Image Name:  Tp_D_CNN_S_B_ind00018_ind00089_00007.tif
# Image Name:  Tp_S_NRN_M_N_art00015_art00015_10272.tif
# Epoch count:  43
# Image Name:  Tp_S_NNN_S_N_sec00098_sec00098_10334.tif
# Image Name:  Tp_S_NNN_S_B_nat10003_nat10003_20071.jpg
# Image Name:  Tp_S_NNN_S_N_nat00078_nat00078_00675.tif
# Image Name:  Tp_S_NNN_S_B_sec00013_sec00013_11229.jpg
# Train loss:  1.1990408897399902  acc:  0.9421005249023438 Train dice: 0.49415671825408936  Test loss:  1.2531746625900269  acc:  0.8669376373291016 Test dice: 0.43590259552001953
# Model with best loss found..
# Epoch count:  44
# Image Name:  Tp_S_NNN_S_N_ind00031_ind00031_01324.tif
# Image Name:  Tp_D_NRN_S_N_nat00039_ani00013_00653.tif
# Image Name:  Tp_D_NRN_S_B_ind00007_cha00040_00425.tif
# Image Name:  Tp_S_CNN_S_N_cha00017_cha00017_10311.tif
# Train loss:  1.2135205268859863  acc:  0.8982391357421875 Train dice: 0.47555679082870483  Test loss:  1.2490777969360352  acc:  0.8693790435791016 Test dice: 0.4358873963356018
# Epoch count:  45
# Image Name:  Tp_S_NNN_S_N_ind00010_ind00010_01308.tif
# Image Name:  Tp_D_CRN_S_B_pla00041_pla00040_10978.jpg
# Image Name:  Tp_S_NNN_S_B_ani00060_ani00060_00180.tif
# Image Name:  Tp_S_NRN_S_N_arc10128_arc10128_11896.jpg
# Train loss:  1.1990160942077637  acc:  0.9073944091796875 Train dice: 0.48594930768013  Test loss:  1.2449933290481567  acc:  0.8693561553955078 Test dice: 0.435869038105011
# Model with best loss found..
# Epoch count:  46
# Image Name:  Tp_S_NNN_S_N_art20080_art20080_02315.tif
# Image Name:  Tp_D_NRN_M_N_art10115_cha00067_11527.jpg
# Image Name:  Tp_S_CNN_M_N_arc00065_arc00065_10254.tif
# Image Name:  Tp_S_NNN_S_N_pla20087_pla20087_02355.tif
# Train loss:  1.2117509841918945  acc:  0.8927402496337891 Train dice: 0.4691114127635956  Test loss:  1.240923523902893  acc:  0.8692417144775391 Test dice: 0.43584591150283813
# Epoch count:  47
# Image Name:  Tp_S_CRN_S_N_txt00073_txt00073_01291.tif
# Image Name:  Tp_S_NNN_S_N_arc20084_arc20084_02417.tif
# Image Name:  Tp_D_NRN_S_N_arc00016_sec00045_11699.jpg
# Image Name:  Tp_D_NRN_M_N_nat10148_nat10161_12121.jpg
# Train loss:  1.1956138610839844  acc:  0.8884544372558594 Train dice: 0.48115554451942444  Test loss:  1.2368721961975098  acc:  0.8683109283447266 Test dice: 0.4358149766921997
# Model with best loss found..
# Epoch count:  48
# Image Name:  Tp_S_NND_S_N_sec00007_sec00007_00769.tif
# Image Name:  Tp_D_NRN_S_N_pla10120_ani10122_11607.jpg
# Image Name:  Tp_S_CRN_M_N_ind00027_ind00027_10396.tif
# Image Name:  Tp_S_NNN_S_B_arc00025_arc00025_01097.tif
# Train loss:  1.1796298027038574  acc:  0.9208660125732422 Train dice: 0.4930574297904968  Test loss:  1.232836127281189  acc:  0.8675937652587891 Test dice: 0.4357801079750061
# Model with best loss found..
# Epoch count:  49
# Image Name:  Tp_S_NNN_S_N_arc00022_arc00022_01120.tif
# Image Name:  Tp_S_CNN_M_N_txt00100_txt00100_10155.tif
# Image Name:  Tp_D_NRN_S_N_nat00020_ani00005_00638.tif
# Image Name:  Tp_S_NRD_S_N_cha00069_cha00069_00389.tif
# Train loss:  1.2178597450256348  acc:  0.8650684356689453 Train dice: 0.4507565498352051  Test loss:  1.2288193702697754  acc:  0.8663272857666016 Test dice: 0.4357379674911499
# Epoch count:  50
# Image Name:  Tp_S_NNN_S_N_ind20003_ind20003_01744.tif
# Image Name:  Tp_S_NNN_M_N_arc10118_arc10118_10779.jpg
# Image Name:  Tp_S_NNN_S_N_nat00044_nat00044_00658.tif
# Image Name:  Tp_D_NNN_S_N_nat20082_nat20090_01586.tif
# Train loss:  1.1776554584503174  acc:  0.9276351928710938 Train dice: 0.4869019389152527  Test loss:  1.224811315536499  acc:  0.8659915924072266 Test dice: 0.4356997609138489
# Model with best loss found..
# Epoch count:  51
# Image Name:  Tp_S_NNN_S_N_nat00035_nat00035_00955.tif
# Image Name:  Tp_D_NRN_S_B_ani00067_ani00062_11127.jpg
# Image Name:  Tp_D_NRN_S_N_nat10162_art00021_12086.jpg
# Image Name:  Tp_D_NRD_S_N_ani00078_ani00077_00198.tif
# Train loss:  1.170457124710083  acc:  0.9299068450927734 Train dice: 0.4900539517402649  Test loss:  1.2208149433135986  acc:  0.8634967803955078 Test dice: 0.4356631636619568
# Model with best loss found..
# Epoch count:  52
# Image Name:  Tp_S_CRN_S_B_pla00039_pla00039_10980.jpg
# Image Name:  Tp_S_CNN_S_N_art20068_art20068_02322.tif
# Image Name:  Tp_S_CNN_M_N_cha00023_cha00023_10722.jpg
# Image Name:  Tp_D_NRN_M_N_art10115_cha00067_11527.jpg
# Train loss:  1.2035996913909912  acc:  0.8699417114257812 Train dice: 0.4528784453868866  Test loss:  1.2168307304382324  acc:  0.8512134552001953 Test dice: 0.4356282353401184
# Epoch count:  53
# Image Name:  Tp_D_NNN_S_N_nat20019_nat20015_02219.tif
# Image Name:  Tp_S_NNN_S_B_ind00030_ind00030_20114.jpg
# Image Name:  Tp_S_NNN_S_B_cha10132_cha10132_12215.jpg
# Image Name:  Tp_S_NRN_S_B_cha10211_cha10211_12330.jpg
# Train loss:  1.1593070030212402  acc:  0.9311962127685547 Train dice: 0.4931519329547882  Test loss:  1.212859869003296  acc:  0.8359851837158203 Test dice: 0.43559402227401733
# Model with best loss found..
# Epoch count:  54
# Image Name:  Tp_S_NRN_S_N_art20051_art20051_01857.tif
# Image Name:  Tp_S_NNN_S_B_ani00056_ani00056_00176.tif
# Image Name:  Tp_D_NNN_S_N_ani00010_ani00017_10215.tif
# Image Name:  Tp_S_NRN_S_N_ani10128_ani10128_12461.jpg
# Train loss:  1.1629825830459595  acc:  0.9141864776611328 Train dice: 0.48547136783599854  Test loss:  1.2089059352874756  acc:  0.8233737945556641 Test dice: 0.43555790185928345
# Image Name:  Tp_D_NRN_M_N_nat10116_cha00031_11368.jpg
# Image Name:  Tp_D_NNN_S_B_arc20098_arc20030_02198.tif
# Image Name:  Tp_S_CRN_S_N_nat10168_nat10168_12101.jpg
# Image Name:  Tp_S_CRN_M_N_arc00073_arc00073_10266.tif
# Train loss:  1.1451869010925293  acc:  0.4213237762451172 Train dice: 0.4530424475669861  Test loss:  1.162306785583496  acc:  0.3936786651611328 Test dice: 0.43219196796417236
# Epoch count:  68
# Image Name:  Tp_S_NRN_S_N_pla20027_pla20027_01927.tif
# Image Name:  Tp_D_NRN_S_B_cha00036_cha00070_11738.jpg
# Image Name:  Tp_S_CRN_M_N_arc10111_arc10111_10730.jpg
# Image Name:  Tp_S_NNN_S_B_arc20013_arc20013_02156.tif
# Train loss:  1.1067767143249512  acc:  0.4767780303955078 Train dice: 0.48772215843200684  Test loss:  1.1588034629821777  acc:  0.3936786651611328 Test dice: 0.4319828152656555
# Model with best loss found..
# Epoch count:  69
# Image Name:  Tp_S_NNN_S_N_cha20008_cha20008_02007.tif
# Image Name:  Tp_S_CNN_M_N_art00047_art00047_10506.tif
# Image Name:  Tp_S_NRN_S_N_sec00028_sec00028_10783.jpg
# Image Name:  Tp_D_NRN_S_B_sec00089_ani00070_00718.tif
# Train loss:  1.1023693084716797  acc:  0.47788047790527344 Train dice: 0.48841699957847595  Test loss:  1.1553376913070679  acc:  0.3936786651611328 Test dice: 0.43175405263900757
# Model with best loss found..
# Epoch count:  70
# Image Name:  Tp_D_NNN_S_N_cha10195_cha10188_12321.jpg
# Image Name:  Tp_S_CNN_M_B_nat00057_nat00057_11104.jpg
# Image Name:  Tp_S_NNN_S_B_nat00074_nat00074_00980.tif
# Image Name:  Tp_S_NNN_S_N_ind20064_ind20064_01805.tif
# Train loss:  1.0972363948822021  acc:  0.4808311462402344 Train dice: 0.4898553490638733  Test loss:  1.1518497467041016  acc:  0.3936786651611328 Test dice: 0.431565523147583
# Model with best loss found..
# Epoch count:  71
# Image Name:  Tp_S_CRN_S_N_ind00050_ind00050_10899.jpg
# Image Name:  Tp_S_NND_S_N_ani00086_ani00086_00815.tif
# Image Name:  Tp_S_NNN_S_N_arc20072_arc20072_02463.tif
# Image Name:  Tp_S_NNN_S_N_pla00015_pla00015_00554.tif
# Train loss:  1.088731050491333  acc:  0.48960113525390625 Train dice: 0.49468424916267395  Test loss:  1.148343563079834  acc:  0.3936786651611328 Test dice: 0.43141382932662964
# Model with best loss found..
# Epoch count:  72
# Image Name:  Tp_S_NRD_S_B_sec20033_sec20033_01623.tif
# Image Name:  Tp_D_NRN_S_B_arc00042_ani00070_00262.tif
# Image Name:  Tp_D_NRN_S_B_ind00007_cha00040_00425.tif
# Image Name:  Tp_S_NNN_S_B_sec20041_sec20041_02447.tif
# Train loss:  1.1028704643249512  acc:  0.4574451446533203 Train dice: 0.4768868088722229  Test loss:  1.1448142528533936  acc:  0.3936786651611328 Test dice: 0.4313034415245056
# Epoch count:  73
# Image Name:  Tp_S_NND_S_N_ani00074_ani00074_00194.tif
# Epoch count:  138
# Image Name:  Tp_D_CRN_M_N_arc00045_arc00071_10087.tif
# Image Name:  Tp_D_NRN_S_N_ind00091_cha00063_00486.tif
# Image Name:  Tp_D_NRN_S_N_arc00013_sec00045_11700.jpg
# Image Name:  Tp_S_NNN_S_N_art10110_art10110_11571.jpg
# Train loss:  0.895108699798584  acc:  0.47325706481933594 Train dice: 0.4857463240623474  Test loss:  0.9481220841407776  acc:  0.3936786651611328 Test dice: 0.43033337593078613
# Model with best loss found..
# Epoch count:  139
# Image Name:  Tp_D_NNN_S_N_ani10179_ani10175_12487.jpg
# Image Name:  Tp_D_CRN_S_B_cha00082_cha00050_00402.tif
# Image Name:  Tp_S_NRD_S_B_art00070_art00070_01029.tif
# Image Name:  Tp_S_CNN_M_N_cha00073_cha00073_11026.jpg
# Train loss:  0.8997511267662048  acc:  0.45923423767089844 Train dice: 0.4787043333053589  Test loss:  0.9458357691764832  acc:  0.3936786651611328 Test dice: 0.4302366375923157
# Epoch count:  140
# Image Name:  Tp_S_NRD_M_B_sec00064_sec00064_00085.tif
# Image Name:  Tp_D_NRN_S_N_art00033_ani00013_00511.tif
# Image Name:  Tp_S_NNN_S_B_nat00098_nat00098_00999.tif
# Image Name:  Tp_D_NRN_S_N_arc20044_arc20039_01497.tif
# Train loss:  0.8862238526344299  acc:  0.4802532196044922 Train dice: 0.4898485541343689  Test loss:  0.9435743689537048  acc:  0.3936786651611328 Test dice: 0.43013134598731995
# Model with best loss found..
# Epoch count:  141
# Image Name:  Tp_S_CNN_S_N_cha10118_cha10118_12196.jpg
# Image Name:  Tp_D_NRD_S_O_nat20021_nat20001_01525.tif
# Image Name:  Tp_S_CRN_M_N_txt00007_txt00007_10841.jpg
# Image Name:  Tp_D_NRN_S_B_ani00028_ani00029_20111.jpg
# Train loss:  0.9381396770477295  acc:  0.39403724670410156 Train dice: 0.4355660080909729  Test loss:  0.9413442015647888  acc:  0.3936786651611328 Test dice: 0.43001100420951843
# Epoch count:  142
# Image Name:  Tp_S_NNN_S_N_ind20020_ind20020_01761.tif
# Image Name:  Tp_S_NRN_S_N_arc20004_arc20004_02152.tif
# Image Name:  Tp_D_NRN_S_N_ind00083_ind00077_00480.tif
# Image Name:  Tp_S_CNN_S_N_art20086_art20086_01892.tif
# Train loss:  0.8750705718994141  acc:  0.4927024841308594 Train dice: 0.4962846636772156  Test loss:  0.9391037225723267  acc:  0.3936786651611328 Test dice: 0.42991718649864197
# Model with best loss found..
# Epoch count:  143
# Image Name:  Tp_S_NRN_S_N_ind00043_ind00043_10890.jpg
# Image Name:  Tp_S_CNN_S_N_sec00022_sec00022_00043.tif
# Image Name:  Tp_S_NRN_S_N_nat10141_nat10141_11959.jpg
# Image Name:  Tp_D_NRN_M_N_art10108_cha10110_11575.jpg
# Train loss:  0.8749277591705322  acc:  0.48845672607421875 Train dice: 0.49409323930740356  Test loss:  0.9368946552276611  acc:  0.3936786651611328 Test dice: 0.4298081398010254
# Model with best loss found..
# Epoch count:  144
# Image Name:  Tp_D_NNN_M_B_arc00054_nat10136_11920.jpg
# Image Name:  Tp_D_CRD_S_B_sec00049_ani00047_00070.tif
# Image Name:  Tp_S_NNN_S_N_sec00065_sec00065_00788.tif
# Image Name:  Tp_S_NNN_S_N_nat00008_nat00008_00628.tif
# Train loss:  0.9145472049713135  acc:  0.4169788360595703 Train dice: 0.45215561985969543  Test loss:  0.9346922039985657  acc:  0.3936786651611328 Test dice: 0.42970842123031616
# Epoch count:  145
# Image Name:  Tp_S_NNN_S_N_pla00013_pla00013_10966.jpg
# Image Name:  Tp_D_NNN_M_N_nat00048_nat00053_11076.jpg
# Image Name:  Tp_D_CRN_S_N_sec00014_cha00086_11402.jpg
# Image Name:  Tp_D_CRN_M_N_pla00035_pla00033_10997.jpg
# Train loss:  0.8706603050231934  acc:  0.4876861572265625 Train dice: 0.49374035000801086  Test loss:  0.9325240850448608  acc:  0.3936786651611328 Test dice: 0.42959028482437134
# Model with best loss found..
# Epoch count:  146
# Image Name:  Tp_D_NRN_S_N_sec00071_ind00084_11277.jpg
# Image Name:  Tp_S_NNN_S_N_sec00069_sec00069_00787.tif
# Image Name:  Tp_D_NRN_M_N_cha00031_pla00050_11388.jpg
# Image Name:  Tp_S_NNN_S_N_nat20094_nat20094_02456.tif
# Train loss:  0.8745984435081482  acc:  0.47601318359375 Train dice: 0.487515926361084  Test loss:  0.9303776025772095  acc:  0.3936786651611328 Test dice: 0.42946624755859375
# Epoch count:  147
# Image Name:  Tp_S_NNN_S_N_sec20073_sec20073_01663.tif
# Image Name:  Tp_D_NRN_M_N_nat00033_cha00070_11476.jpg
# Image Name:  Tp_S_NNN_S_N_ani20048_ani20048_02091.tif
# Image Name:  Tp_S_NNN_S_N_cha00073_cha00073_00393.tif
# Train loss:  0.8753790855407715  acc:  0.4705181121826172 Train dice: 0.48446470499038696  Test loss:  0.9282154440879822  acc:  0.3936786651611328 Test dice: 0.429373562335968
# Epoch count:  148
# Image Name:  Tp_S_NNN_S_B_nat00065_nat00065_00975.tif
# Image Name:  Tp_D_CND_S_N_ind00078_ind00077_00476.tif
# Image Name:  Tp_D_NRN_M_B_sec00002_nat10123_11396.jpg
# Image Name:  Tp_S_NNN_S_N_ind00013_ind00013_00887.tif
# Train loss:  0.8758215308189392  acc:  0.46585655212402344 Train dice: 0.481767475605011  Test loss:  0.9260771870613098  acc:  0.3936786651611328 Test dice: 0.42927250266075134
# Epoch count:  149
# Image Name:  Tp_S_NNN_S_N_sec00035_sec00035_00056.tif
# Image Name:  Tp_S_CNN_M_N_ind00088_ind00088_10638.jpg
# Image Name:  Tp_S_NRD_S_N_pla20007_pla20007_01907.tif
# Image Name:  Tp_S_CNN_S_N_pla00036_pla00036_00571.tif
# Train loss:  0.9149758219718933  acc:  0.4071083068847656 Train dice: 0.4403739273548126  Test loss:  0.9239704012870789  acc:  0.3936786651611328 Test dice: 0.4291555881500244
# .........Training is Done .............
